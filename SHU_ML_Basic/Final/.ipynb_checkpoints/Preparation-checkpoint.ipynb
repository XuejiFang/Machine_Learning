# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
def load_data(fileName):
    data = pd.read_excel(fileName)
    return data

# %%
path = './Data/data.xlsx'
data = load_data(path)

# %%
data.head()
# Out:
#      pre     2W     4W     6W    8W  10W    12W  label
# 0  77.83    NaN  0.026    NaN   NaN  NaN  0.003      0
# 1   5.37  0.123    NaN  0.168   NaN  NaN  0.296      0
# 2  23.29  0.192    NaN  0.027   NaN  NaN  0.060      0
# 3  20.00    NaN    NaN  0.060   NaN  NaN  0.035      0
# 4   4.66  0.122  0.010    NaN  0.01  NaN  0.010      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pre     226 non-null    float64
#  1   2W      205 non-null    float64
#  2   4W      176 non-null    float64
#  3   6W      166 non-null    float64
#  4   8W      39 non-null     float64
#  5   10W     58 non-null     float64
#  6   12W     33 non-null     float64
#  7   label   227 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 14.3 KB

# %%
sns.pairplot(data)

# %%
data.head()
# Out:
#      pre     2W     4W     6W    8W  10W    12W  label
# 0  77.83    NaN  0.026    NaN   NaN  NaN  0.003      0
# 1   5.37  0.123    NaN  0.168   NaN  NaN  0.296      0
# 2  23.29  0.192    NaN  0.027   NaN  NaN  0.060      0
# 3  20.00    NaN    NaN  0.060   NaN  NaN  0.035      0
# 4   4.66  0.122  0.010    NaN  0.01  NaN  0.010      0

# %%
sns.scatterplot(x='pre',y='2W',hue='label',data=data)
# Out:
# <AxesSubplot:xlabel='pre', ylabel='2W'>

# %%
sns.scatterplot(x='2W',y='4W',hue='label',data=data)
# Out:
# <AxesSubplot:xlabel='2W', ylabel='4W'>

# %%
sns.scatterplot(x='4W',y='6W',hue='label',data=data)
# Out:
# <AxesSubplot:xlabel='4W', ylabel='6W'>

# %%
sns.scatterplot(x='6W',y='8W',hue='label',data=data)
# Out:
# <AxesSubplot:xlabel='6W', ylabel='8W'>

# %%
sns.scatterplot(x='8W',y='10W',hue='label',data=data)
# Out:
# <AxesSubplot:xlabel='8W', ylabel='10W'>

# %%
sns.scatterplot(x='10W',y='12W',hue='label',data=data)
# Out:
# <AxesSubplot:xlabel='10W', ylabel='12W'>
