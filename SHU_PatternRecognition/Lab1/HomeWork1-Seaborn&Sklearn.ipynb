# %%
import matplotlib.pyplot as plt
import pandas as pd
import warnings
import seaborn as sns

# plt.style.use(['science','no-latex'])
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False   # 解决保存图像是负号'-'显示为方块的问题

warnings.filterwarnings('ignore')

# %%
# darkgrid, whitegrid, dark, white, ticks
sns.set_theme(style='white', rc={'font.sans-serif': 'SimHei', 'axes.unicode_minus': False})

# %% [markdown]
# ## 1. 熟悉附件一里所有数据集

# %% [markdown]
# ## 2. 可视化附件一数据集 1和附件一数据集2中的样本

# %% [markdown]
# ### 2.1 数据集1

# %%
data1=pd.read_excel('../实验数据/genderdata/2021冬模式识别数据收集.xlsx',index_col=0)

# %%
data1=data1.dropna(axis=1)
data1.head()
# Out:
#    性别  身高(cm)  体重(kg)  脚长(mm)  尺码
# 序号
# 1   男     171      58     245  39
# 2   男     175      72     260  42
# 3   男     183      65     265  43
# 4   男     180      90     265  43
# 5   女     160      53     230  36

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 53
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   性别      51 non-null     object
#  1   身高(cm)  51 non-null     int64
#  2   体重(kg)  51 non-null     int64
#  3   脚长(mm)  51 non-null     int64
#  4   尺码      51 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.4+ KB

# %%
sns.pairplot(data1, hue='性别')

# %%
sns.relplot(x='身高(cm)',y='体重(kg)',col='性别',data=data1)

# %%
sns.lmplot(x='身高(cm)',y='体重(kg)',data=data1,hue='性别',ci=95)

# %%
sns.lmplot(x='身高(cm)',y='脚长(mm)',hue='性别',data=data1)

# %%
sns.lmplot(x='体重(kg)',y='脚长(mm)',hue='性别',data=data1)

# %%
sns.stripplot(x='尺码',y='身高(cm)',data=data1,hue='性别')
# Out:
# <AxesSubplot:xlabel='尺码', ylabel='身高(cm)'>

# %%
sns.boxplot(x='尺码',y='身高(cm)',data=data1,hue='性别')
# Out:
# <AxesSubplot:xlabel='尺码', ylabel='身高(cm)'>

# %%
sns.violinplot(y='身高(cm)',x='尺码',data=data1,hue='性别')
# Out:
# <AxesSubplot:xlabel='尺码', ylabel='身高(cm)'>

# %% [markdown]
# ## 2.2 数据集2

# %%
data2=pd.read_csv('../实验数据/iris.dat',header=None,sep='  | ')

# %%
data2.columns=['Sepal.Length','Sepal.Width','Petal.Length','Petal.Width','Class']
data2['Class']=data2['Class'].map({1:'Setosa',2:'Versicolour',3:'Virginica'})

# %%
data2.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width   Class
# 0            51           35            14            2  Setosa
# 1            49           30            14            2  Setosa
# 2            47           32            13            2  Setosa
# 3            46           31            15            2  Setosa
# 4            50           36            14            2  Setosa

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    int64
#  1   Sepal.Width   150 non-null    int64
#  2   Petal.Length  150 non-null    int64
#  3   Petal.Width   150 non-null    int64
#  4   Class         150 non-null    object
# dtypes: int64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.pairplot(data2,hue='Class')

# %% [markdown]
# ## 3. 数据集1每个维度的直方图

# %%
sns.histplot(data=data1)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data=data1['身高(cm)'],kde=True)
# Out:
# <AxesSubplot:xlabel='身高(cm)', ylabel='Count'>

# %%
sns.histplot(data=data1['体重(kg)'],kde=True)
# Out:
# <AxesSubplot:xlabel='体重(kg)', ylabel='Count'>

# %%
sns.histplot(data=data1['脚长(mm)'],kde=True)
# Out:
# <AxesSubplot:xlabel='脚长(mm)', ylabel='Count'>

# %%
sns.histplot(data=data1['尺码'],kde=True)
# Out:
# <AxesSubplot:xlabel='尺码', ylabel='Count'>

# %% [markdown]
# ## 4. 每个维度不同类别数据的直方图

# %%
fig = plt.figure(figsize=[10,10])

ax1 = fig.add_subplot(221)
sns.histplot(data=data1,x='身高(cm)',hue='性别',kde=True,ax=ax1)

ax2 = fig.add_subplot(222)
sns.histplot(data=data1,x='体重(kg)',hue='性别',kde=True,ax=ax2)

ax3 = fig.add_subplot(223)
sns.histplot(data=data1,x='脚长(mm)',hue='性别',kde=True,ax=ax3)

ax4 = fig.add_subplot(224)
sns.histplot(data=data1,x='尺码',hue='性别',kde=True,ax=ax4)
# Out:
# <AxesSubplot:xlabel='尺码', ylabel='Count'>

# %%
fig = plt.figure(figsize=[10,10])

ax1 = fig.add_subplot(221)
sns.histplot(data=data2,x='Sepal.Length',hue='Class',kde=True,ax=ax1)

ax2 = fig.add_subplot(222)
sns.histplot(data=data2,x='Sepal.Width',hue='Class',kde=True,ax=ax2)

ax3 = fig.add_subplot(223)
sns.histplot(data=data2,x='Petal.Length',hue='Class',kde=True,ax=ax3)

ax4 = fig.add_subplot(224)
sns.histplot(data=data2,x='Petal.Width',hue='Class',kde=True,ax=ax4)
# Out:
# <AxesSubplot:xlabel='Petal.Width', ylabel='Count'>

# %% [markdown]
# ## 5. 熟悉Sklearn

# %% [markdown]
# ### 5.1 拟合与预测

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(random_state=0)
X = [[1,2,3],[11,12,13]]
y = [0,1]
clf.fit(X,y)
clf.predict(X)
# Out:
# array([0, 1])

# %% [markdown]
# ### 5.2 转化器和预处理

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = [[0,15],[1,-10]]
StandardScaler().fit(X).transform(X)
# Out:
# array([[-1.,  1.],
#        [ 1., -1.]])

# %% [markdown]
# ### 5.3 Pipelines
# 把预处理直接和模型塞在一起减少代码量

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
pipe = make_pipeline(
    StandardScaler(),
    LogisticRegression())

# %%
X, y =load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
accuracy_score(pipe.predict(X_test), y_test)
# Out:
# 0.9736842105263158

# %% [markdown]
# ### 5.4 模型评估

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_validate

# %%
X, y = make_regression(n_samples=1000, random_state=0)
lr = LinearRegression()

# %%
result = cross_validate(lr, X, y)

# %%
result['test_score']
# Out:
# array([1., 1., 1., 1., 1.])

# %% [markdown]
# ### 5.5 自动模型调参

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from scipy.stats import randint

# %%
X, y = fetch_california_housing(return_X_y=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
param_distributions = {'n_estimators': randint(1, 5),'max_depth': randint(5,10)}

# %%
search =  RandomizedSearchCV(estimator=RandomForestRegressor(random_state=0),
                             n_iter=5,
                            param_distributions=param_distributions,
                            random_state=0)

# %%
search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(estimator=RandomForestRegressor(random_state=0), n_iter=5,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000002145C08E7C0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000002145C08EA30>},
#                    random_state=0)

# %%
RandomizedSearchCV(estimator=RandomForestRegressor(random_state=0),
                  n_iter=5,
                  param_distributions={'max_depth':...,
                                      'n_estimators':...},
                  random_state=0)
# Out:
# RandomizedSearchCV(estimator=RandomForestRegressor(random_state=0), n_iter=5,
#                    param_distributions={'max_depth': Ellipsis,
#                                         'n_estimators': Ellipsis},
#                    random_state=0)

# %%
search.best_params_
# Out:
# {'max_depth': 9, 'n_estimators': 4}

# %%
search.score(X_test, y_test)
# Out:
# 0.735363411343253
